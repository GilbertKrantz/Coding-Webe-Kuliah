# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Train_data = pd.read_csv('DataTrain_Preliminary.csv', delimiter=';')
Train_data.head()
# Out:
#   duration protocol_type  service flag src_bytes dst_bytes land  \
# 0        0           tcp  private   SH         0         0    0
# 1        0           tcp  private   S0         0         0    0
# 2        0           tcp     http   SF       285      3623    0
# 3        0           tcp     http   SF       232       584    0
# 4        1           tcp     smtp   SF      1080       327    0
#
#   wrong_fragment urgent hot  ... dst_host_srv_count dst_host_same_srv_rate  \
# 0              0      0   0  ...                  1                   0.01
# 1              0      0   0  ...                  5                   0.02
# 2              0      0   0  ...                228                   1.00
# 3              0      0   0  ...                255                   1.00
# 4              0      0   0  ...                154                   0.58
#
#   dst_host_diff_srv_rate dst_host_same_src_port_rate  \
# 0                   0.94                        0.95
# ...

# %% [markdown]
# ## Check Data Overview

# %%
Train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112446 entries, 0 to 112445
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     112446 non-null  object
#  1   protocol_type                111778 non-null  object
#  2   service                      111426 non-null  object
#  3   flag                         111593 non-null  object
#  4   src_bytes                    112446 non-null  object
#  5   dst_bytes                    112446 non-null  object
#  6   land                         112446 non-null  object
#  7   wrong_fragment               112446 non-null  object
#  8   urgent                       112446 non-null  object
#  9   hot                          112446 non-null  object
#  10  num_failed_logins            112446 non-null  object
#  11  logged_in                    112446 non-null  object
# ...

# %%
Train_data.isin(['*']).sum()
# Out:
# duration                         557
# protocol_type                      0
# service                            0
# flag                               0
# src_bytes                        851
# dst_bytes                        706
# land                             264
# wrong_fragment                   523
# urgent                           300
# hot                              918
# num_failed_logins                405
# logged_in                        170
# num_compromised                  352
# root_shell                       152
# su_attempted                     195
# num_root                         234
# num_file_creations               241
# num_shells                       308
# num_access_files                 591
# num_outbound_cmds                186
# is_host_login                     76
# is_guest_login                   319
# count                            228
# srv_count                        209
# serror_rate                     4614
# ...

# %%
Train_data.isin(['99999']).sum()
# Out:
# duration                       363
# protocol_type                    0
# service                          0
# flag                             0
# src_bytes                      197
# dst_bytes                       22
# land                           144
# wrong_fragment                   0
# urgent                          68
# hot                              0
# num_failed_logins              179
# logged_in                        0
# num_compromised                 99
# root_shell                     164
# su_attempted                    79
# num_root                         0
# num_file_creations               0
# num_shells                     181
# num_access_files                33
# num_outbound_cmds                0
# is_host_login                    0
# is_guest_login                 109
# count                          857
# srv_count                      644
# serror_rate                    103
# srv_serror_rate                361
# rerror_rate                    521
# ...

# %%
Train_data['protocol_type'].value_counts()
# Out:
# protocol_type
# tcp     90997
# udp     13364
# icmp     7417
# Name: count, dtype: int64

# %%
Train_data['service'].value_counts()
# Out:
# service
# http         36013
# private      19415
# domain_u      8041
# smtp          6563
# ftp_data      5558
#              ...
# tftp_u           3
# aol              2
# http_8001        1
# harvest          1
# http_2784        1
# Name: count, Length: 70, dtype: int64

# %%
Train_data['flag'].value_counts()
# Out:
# flag
# SF        65941
# S0        31356
# REJ        9956
# RSTR       2155
# RSTO       1364
# S1          314
# SH          222
# S2          115
# RSTOS0       91
# S3           40
# OTH          39
# Name: count, dtype: int64

# %%
Train_data['land'].value_counts()
# Out:
# land
# 0        112015
# *           264
# 99999       144
# 1            23
# Name: count, dtype: int64

# %%
Train_data['wrong_fragment'].value_counts()
# Out:
# wrong_fragment
# 0    110958
# 3       782
# *       523
# 1       183
# Name: count, dtype: int64
