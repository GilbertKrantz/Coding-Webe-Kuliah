# %% [markdown]
# Dengan ini, saya yang bernama Lauren Abigail dengan NIM 2602108426, dengan sungguh-sungguh berjanji bahwa file yang saya submit adalah hasil karya saya sendiri dan bukan merupakan salinan dari pekerjaan teman saya.

# %% [markdown]
# # 1b.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def rhombus_equation(x, a) :
    return a - abs(x)

# Membuat Dataset
x = np.linspace(-10.0, 10.0, 200)
a_value1 = 10
y = rhombus_equation(x, a_value1)
y = np.hstack([y, -y])
x = np.hstack([x, -x])

x1 = np.linspace(-9.0, 9.0, 200)
a_value2 = 50
y1 = rhombus_equation(5*x1, a_value2)
y1 = np.hstack([y1, -y1])
x1 = np.hstack([x1, -x1])

df1 = pd.DataFrame(np.vstack([y, x]).T, columns=['X1', 'X2'])
df1['Y'] = 0
df2 = pd.DataFrame(np.vstack([y1, x1]).T, columns=['X1', 'X2'])
df2['Y'] = 1

# Menggabungkan dataset dengan menggunakan pd.concat
df = pd.concat([df1, df2], ignore_index=True)
df.head()
# Out:
#          X1         X2  Y
# 0  0.000000 -10.000000  0
# 1  0.100503  -9.899497  0
# 2  0.201005  -9.798995  0
# 3  0.301508  -9.698492  0
# 4  0.402010  -9.597990  0

# %%
plt.scatter(y,x)
plt.scatter(y1,x1)

# %%
# Splitting dataset menjadi training set dan test set

from sklearn.model_selection import train_test_split
X = df[['X1', 'X2']]
y = df['Y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # 1c.

# %%
from sklearn.svm import SVC

svm_linear_1 = SVC(kernel='linear', C=1.0)
svm_linear_2 = SVC(kernel='linear', C=100.0)

svm_linear_1.fit(X_train, y_train)
svm_linear_2.fit(X_train, y_train)

y_pred_1 = svm_linear_1.predict(X_test)
y_pred_2 = svm_linear_2.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        83
#            1       0.48      1.00      0.65        77
#
#     accuracy                           0.48       160
#    macro avg       0.24      0.50      0.32       160
# weighted avg       0.23      0.48      0.31       160
# C:\Users\kanek\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kanek\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(classification_report(y_test, y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        83
#            1       0.48      1.00      0.65        77
#
#     accuracy                           0.48       160
#    macro avg       0.24      0.50      0.32       160
# weighted avg       0.23      0.48      0.31       160
# C:\Users\kanek\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kanek\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # 1d.

# %%
from sklearn.svm import SVC

svm_rbf_1 = SVC(kernel='rbf', C=1, gamma=0.1)
svm_rbf_2 = SVC(kernel='rbf', C=100.0, gamma=10)

svm_rbf_1.fit(X_train, y_train)
svm_rbf_2.fit(X_train, y_train)

y_pred_1 = svm_rbf_1.predict(X_test)
y_pred_2 = svm_rbf_2.predict(X_test)

# %%
print(classification_report(y_test, y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        83
#            1       1.00      1.00      1.00        77
#
#     accuracy                           1.00       160
#    macro avg       1.00      1.00      1.00       160
# weighted avg       1.00      1.00      1.00       160

# %%
print(classification_report(y_test, y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        83
#            1       0.97      1.00      0.99        77
#
#     accuracy                           0.99       160
#    macro avg       0.99      0.99      0.99       160
# weighted avg       0.99      0.99      0.99       160

# %% [markdown]
# # 1d.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1e.
#
# - SVM Linear 1 : Kernel Linear, C = 1
# - SVM Linear 2 : Kernel Linear, C = 100
# - SVM RBF 1 : Kernel RBF, C = 1, gamma = 0.1
# - SVM RBF 2 : Kernel RBF, C = 100, gamma = 10

# %% [markdown]
# # 1f.
# Best Model adalah SVM RBF 1 dengan akurasi 1 atau dapat mengklasifikasikan semua data dengan benar dan sempurna, Worst Model adalah SVM Linear 1 dengan akurasi 0.5 atau tidak dapat mengklasifikasikan data dengan benar dan tidak sempurna khususnya Y=0. Hal ini dikarenakan data yang diberikan lebih cocok dengan kernel RBF dari pada kernel Linear.
