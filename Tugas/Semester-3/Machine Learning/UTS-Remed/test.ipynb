# %%
import numpy as np
import pandas as pd
import sklearn.metrics as metrics

# %%
data = pd.read_excel("./lol.xlsx")
data
# Out:
#         ID  Gender Ever Married Graduated     Profession Spending Score  \
# 0   462809    Male           No        No     Healthcare            Low
# 1   462643  Fcmalc          Yes       Yes       Engineer        Average
# 2   466315  Female          Yes       Yes       Engineer            Low
# 3   461735    Male          Yes       Yes         Lawyer           High
# 4   462669  Female          Yes       Yes  Entertainment           High
# 5   461319    Male          Yes        No         Artist        Average
# 6   460156    Male           No       Yes     Healthcare            Low
# 7   464347  Female           No       Yes     Healthcare            Low
# 8   465015  Female          Yes       Yes       Engineer            Low
# 9   465176  Female          Yes       Yes         Artist        Average
# 10  464041  Female           No       Yes       Engineer            Low
# 11  464942    Male           No        No     Healthcare            Low
# ...

# %%
metrics.precision_recall_fscore_support(data["Actual Segmentation"], data["Predicted Segmentation"])
# Out:
# (array([0.875, 0.8  , 0.625, 1.   ]),
#  array([0.7       , 0.88888889, 0.83333333, 0.8       ]),
#  array([0.77777778, 0.84210526, 0.71428571, 0.88888889]),
#  array([10,  9,  6,  5], dtype=int64))

# %%
metrics.accuracy_score(data["Actual Segmentation"],  data["Predicted Segmentation"])
# Out:
# 0.8
