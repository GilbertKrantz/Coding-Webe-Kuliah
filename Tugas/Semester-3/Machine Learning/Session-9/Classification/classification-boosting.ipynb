# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./spotify_songs.csv')
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
# Check for dataset size and basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
# Check for missing value
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
# Drop Null Value
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  0
# track_artist                0
# track_popularity            0
# track_album_id              0
# track_album_name            0
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
# Remove Useless Variables
df.drop(['track_id', 'track_name', 
         'track_album_id', 'track_album_name', 
         'track_album_release_date', 'track_artist', 
         'playlist_name', 'playlist_id'], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32828 entries, 0 to 32832
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_popularity   32828 non-null  int64
#  1   playlist_genre     32828 non-null  object
#  2   playlist_subgenre  32828 non-null  object
#  3   danceability       32828 non-null  float64
#  4   energy             32828 non-null  float64
#  5   key                32828 non-null  int64
#  6   loudness           32828 non-null  float64
#  7   mode               32828 non-null  int64
#  8   speechiness        32828 non-null  float64
#  9   acousticness       32828 non-null  float64
#  10  instrumentalness   32828 non-null  float64
#  11  liveness           32828 non-null  float64
#  12  valence            32828 non-null  float64
#  13  tempo              32828 non-null  float64
#  14  duration_ms        32828 non-null  int64
# dtypes: float64(9), int64(4), object(2)
# ...

# %%
# Check for outliers
def find_outliers(col):
    q1 = col.quantile(.25)
    q3 = col.quantile(.75)
    IQR = q3 - q1
    ll = q1 - (1.5*IQR)
    ul = q3 + (1.5*IQR)
    upper_outliers = col[col > ul].index.tolist()
    lower_outliers = col[col < ll].index.tolist()
    bad_indices = list(set(upper_outliers + lower_outliers))
    return(bad_indices)

import numpy as np
bad_indexes = []
for col in df.columns:
    if df[col].dtype in ["int64","float64"]:
        bad_indexes.append(find_outliers(df[col]))

bad_indexes = set(list(np.concatenate(bad_indexes).flat))
print(len(bad_indexes))
# Out:
# 13605

# %% [markdown]
# Ignore Outliers for now

# %%
# Preprocessing
# One Hot Encoding
ohe_data = pd.get_dummies(df, columns=['playlist_genre'], dtype=int)
ohe_data.head()
# Out:
#    track_popularity playlist_subgenre  danceability  energy  key  loudness  \
# 0                66         dance pop         0.748   0.916    6    -2.634
# 1                67         dance pop         0.726   0.815   11    -4.969
# 2                70         dance pop         0.675   0.931    1    -3.432
# 3                60         dance pop         0.718   0.930    7    -3.778
# 4                69         dance pop         0.650   0.833    1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms  playlist_genre_edm  playlist_genre_latin  \
# ...

# %%
ohe_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32828 entries, 0 to 32832
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_popularity      32828 non-null  int64
#  1   playlist_subgenre     32828 non-null  object
#  2   danceability          32828 non-null  float64
#  3   energy                32828 non-null  float64
#  4   key                   32828 non-null  int64
#  5   loudness              32828 non-null  float64
#  6   mode                  32828 non-null  int64
#  7   speechiness           32828 non-null  float64
#  8   acousticness          32828 non-null  float64
#  9   instrumentalness      32828 non-null  float64
#  10  liveness              32828 non-null  float64
#  11  valence               32828 non-null  float64
#  12  tempo                 32828 non-null  float64
#  13  duration_ms           32828 non-null  int64
#  14  playlist_genre_edm    32828 non-null  int32
# ...

# %% [markdown]
# ## Classification

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# #### Split Data

# %%
input_df = ohe_data.drop('playlist_subgenre', axis=1)
output_df = ohe_data['playlist_subgenre']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(input_df, output_df, test_size=0.25, random_state=1)

# %% [markdown]
# #### Decission Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt_class = DecisionTreeClassifier()
dt_boost = AdaBoostClassifier(estimator=dt_class, n_estimators=10, random_state=1)
dt_boost.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=10,
#                    random_state=1)

# %%
predict_dt = dt_boost.predict(x_test)

# %%
print('Classification Report')
print(classification_report(y_test, predict_dt))
# Out:
# Classification Report
#                            precision    recall  f1-score   support
#
#                album rock       0.29      0.28      0.29       279
#                  big room       0.32      0.33      0.33       277
#              classic rock       0.30      0.29      0.29       349
#                 dance pop       0.35      0.37      0.36       326
#             electro house       0.38      0.43      0.40       346
#                electropop       0.34      0.33      0.33       369
#              gangster rap       0.36      0.41      0.39       344
#                 hard rock       0.47      0.49      0.48       380
#                   hip hop       0.47      0.46      0.47       351
#                   hip pop       0.35      0.32      0.33       314
#           indie poptimism       0.45      0.46      0.46       435
#             latin hip hop       0.38      0.40      0.39       396
#                 latin pop       0.28      0.25      0.26       318
# ...

# %% [markdown]
# #### Logistic Regresion

# %%
from sklearn.linear_model import LogisticRegression

lr_class = LogisticRegression()
lr_boost = AdaBoostClassifier(estimator=lr_class, n_estimators=10, random_state=1)
lr_boost.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=LogisticRegression(), n_estimators=10,
#                    random_state=1)

# %%
predict_lr = lr_boost.predict(x_test)

# %%
print('Classification Report')
print(classification_report(y_test, predict_lr))
# Out:
# Classification Report
#                            precision    recall  f1-score   support
#
#                album rock       0.00      0.00      0.00       279
#                  big room       0.08      0.20      0.12       277
#              classic rock       0.00      0.00      0.00       349
#                 dance pop       0.00      0.00      0.00       326
#             electro house       0.10      0.11      0.10       346
#                electropop       0.00      0.00      0.00       369
#              gangster rap       0.00      0.00      0.00       344
#                 hard rock       0.00      0.00      0.00       380
#                   hip hop       0.10      0.43      0.16       351
#                   hip pop       0.00      0.00      0.00       314
#           indie poptimism       0.35      0.01      0.03       435
#             latin hip hop       0.04      0.09      0.05       396
#                 latin pop       0.00      0.00      0.00       318
# ...

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb_class = GaussianNB()
nb_boost = AdaBoostClassifier(estimator=nb_class, n_estimators=10, random_state=1)
nb_boost.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=GaussianNB(), n_estimators=10, random_state=1)

# %%
predict_nb = nb_boost.predict(x_test)

# %%
print('Classification Report')
print(classification_report(y_test, predict_nb))
# Out:
# Classification Report
#                            precision    recall  f1-score   support
#
#                album rock       0.18      0.03      0.04       279
#                  big room       0.03      0.00      0.01       277
#              classic rock       0.18      0.01      0.02       349
#                 dance pop       0.00      0.00      0.00       326
#             electro house       0.05      0.01      0.02       346
#                electropop       0.17      0.00      0.01       369
#              gangster rap       0.28      0.05      0.08       344
#                 hard rock       0.30      0.06      0.09       380
#                   hip hop       0.29      0.06      0.10       351
#                   hip pop       0.33      0.00      0.01       314
#           indie poptimism       0.50      0.00      0.00       435
#             latin hip hop       0.46      0.03      0.06       396
#                 latin pop       0.29      0.01      0.02       318
# ...
