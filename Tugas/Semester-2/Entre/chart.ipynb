# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("./pakai sheet 1.xlsx", 1)
df
# Out:
#                      Nama  Usia (tahun)   Pekerjaan Penghasilan per bulan  \
# 0                  Nabeel            19   Mahasiswa             3-10 juta
# 1                     Nia            23  Freelancer             3-10 juta
# 2             Sarah Alifa            23    Karyawan             3-10 juta
# 3                   aping            19   Mahasiswa              < 3 juta
# 4                   Hanif            18     Pelajar             3-10 juta
# 5                    Tata            25    Desainer             3-10 juta
# 6     Marvel Martawidjaja            18   Mahasiswa             3-10 juta
# 7                  sausan            18   Mahasiswa              < 3 juta
# 8  Richter Wisearth Satio            19   Mahasiswa              < 3 juta
# 9         Livia Laurencia            18   Mahasiswi              < 3 juta
#
#   Apakah anda menggunakan media sosial?  \
# 0                                    Ya
# 1                                    Ya
# ...

# %%
plt.pie(df["Usia (tahun)"])
# Out:
# ([<matplotlib.patches.Wedge at 0x23266528df0>,
# ...
#  [Text(1.0513723174894851, 0.32344435381807113, ''),
#   Text(0.6325057780902144, 0.8999646885753312, ''),
#   Text(-0.12070775550792136, 1.0933570495315061, ''),
#   Text(-0.7655040880850529, 0.7899389160720415, ''),
#   Text(-1.0735084435245696, 0.23995754141400938, ''),
#   Text(-0.9878303170254059, -0.48393312013695255, ''),
#   Text(-0.4683571759915193, -0.9953097787609891, ''),
#   Text(0.1378666304884121, -1.0913261621521642, ''),
#   Text(0.714392915814223, -0.8364465086510031, ''),
#   Text(1.056323079529793, -0.30689012961106205, '')])
