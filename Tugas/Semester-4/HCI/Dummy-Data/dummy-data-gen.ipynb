# %%
import json
import random

# Define default avatars
defaultAvatar = 'defaultAvatar'
instructorDefaultAvatar = 'instructorDefaultAvatar'

# Generate a random GPA between 0.00 and 4.00
def random_gpa():
    return round(random.uniform(0, 4), 2)

# Generate a random value for totalAttendance (50-100), SATPoints (0-500), and comservHours (0-50)
def random_attendance():
    return random.randint(50, 100)

def random_sat_points():
    return random.randint(0, 500)

def random_comserv_hours():
    return random.randint(0, 50)

# Generate random attendance details
def random_attendance_details(course, mustAttend):
    attended = random.randint(0, mustAttend)
    return {
        "course": course,
        "attendanceStatus": round((attended / mustAttend) * 100, 2),
        "attended": attended,
        "mustAttend": mustAttend,
        "canAbsent": mustAttend - attended
    }

# Define a template for a student
def generate_student(id, name, nim, email):
    student = {
        "id": id,
        "name": name,
        "nim": nim,
        "avatar": defaultAvatar,
        "email": email,
        "password": "a",
        "classes": [
            {"instructorAvatar": instructorDefaultAvatar, "instructor": "Franz", "course": "Linear Algebra"},
            {"instructorAvatar": instructorDefaultAvatar, "instructor": "Franz", "course": "Calculus"},
            {"instructorAvatar": instructorDefaultAvatar, "instructor": "Franz", "course": "Human Computer Interaction"},
            {"instructorAvatar": instructorDefaultAvatar, "instructor": "Franz", "course": "Model Deployment"},
            {"instructorAvatar": instructorDefaultAvatar, "instructor": "Franz", "course": "Artificial Intelligence"}
        ],
        "cummulativeGPA": round(random.uniform(0, 4), 2),
        "totalAttendance": random_attendance(),
        "SATPoints": random_sat_points(),
        "comservHours": random_comserv_hours(),
        "GPA": [
            {
                "semester": "Overall",
                "details": [
                    {"description": "Semester 1", "myGPA": random_gpa(), "classGPA": 3.60, "binusGPA": 3.75},
                    {"description": "Semester 2", "myGPA": random_gpa(), "classGPA": 3.50, "binusGPA": 3.75},
                    {"description": "Semester 3", "myGPA": random_gpa(), "classGPA": 3.60, "binusGPA": 3.25}
                ]
            },
            {
                "semester": "Semester 1",
                "details": [
                     {
                        "description": 'Algorithm and Programming',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.75,
                    },
                    {
                        "description": 'Calculus',
                        "myGPA": random_gpa(),
                        "classGPA": 3.50,
                        "binusGPA": 3.75,
                    },
                    {
                        "description": 'Character Building: Pancasila',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Discrete Math',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Introduction to Data Science',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Program Design Method',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                ]
            },
            {
                "semester": 'Semester 2',
                "details": [
                    {
                        "description": 'Data Mining and Visualization',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.75,
                    },
                    {
                        "description": 'Scientific Computing',
                        "myGPA": random_gpa(),
                        "classGPA": 3.50,
                        "binusGPA": 3.75,
                    },
                    {
                        "description": 'Character Building: Kewarganegaraan',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Data Structure',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Basic Statistic',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Entrepreneurship: Ideation',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Linear Algebra',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                ],
            },
            {
                "semester": 'Semester 3',
                "details": [
                    {
                        "description": 'Artificial Inteligence',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.75,
                    },
                    {
                        "description": 'Database Technology',
                        "myGPA": random_gpa(),
                        "classGPA": 3.50,
                        "binusGPA": 3.75,
                    },
                    {
                        "description": 'Data Management and Organization',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Machine Learning',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Character Building: Agama',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Bayesian Data Analysis',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Indonesian',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                    {
                        "description": 'Computational Physics',
                        "myGPA": random_gpa(),
                        "classGPA": 3.60,
                        "binusGPA": 3.25,
                    },
                ],

            }
        ],
        "attendance": [
            {
                "semester": "Overall",
                "details": [
                    random_attendance_details("Semester 1", 141),
                    random_attendance_details("Semester 2", 137),
                    random_attendance_details("Semester 3", 135)
                ]
            },
            {
                "semester": "Semester 1",
                "details": [
                    random_attendance_details("Algorithm and Programming", 44),
                    random_attendance_details("Calculus", 26),
                    random_attendance_details("Character Building: Pancasila", 13),
                    random_attendance_details("Discrete Math", 26),
                    random_attendance_details("Introduction to Data Science", 13),
                    random_attendance_details("Program Design Method", 19)
                ]
            },
            {
                "semester": "Semester 2",
                "details": [
                    random_attendance_details("Data Mining and Visualization", 22),
                    random_attendance_details("Scientific Computing", 19),
                    random_attendance_details("Character Building: Kewarganegaraan", 13),
                    random_attendance_details("Data Structure", 44),
                    random_attendance_details("Basic Statistic", 13),
                    random_attendance_details("Entrepreneurship: Ideation", 13),
                    random_attendance_details("Linear Algebra", 13)
                ]
            },
            {
                "semester": "Semester 3",
                "details": [
                    random_attendance_details("Artificial Inteligence", 44),
                    random_attendance_details("Database Technology", 19),
                    random_attendance_details("Data Management and Organization", 13),
                    random_attendance_details("Machine Learning", 20),
                    random_attendance_details("Character Building: Agama", 13),
                    random_attendance_details("Bayesian Data Analysis", 13),
                    random_attendance_details("Indonesian", 13),
                    random_attendance_details("Computational Physics", 19)
                ]
            }
        ]
    }
    return student

# Generate 10 students
students = []

for i in range(1, 11):
    name = f'Student {i}'
    nim = f'26021277{80 + i}'
    email = f'student{i}@binus.ac.id'
    students.append(generate_student(i, name, nim, email))

# Convert to JSON and print
print(json.dumps(students, indent=4))
file = json.dumps(students, indent=4)

# Save to a file
with open('students.json', 'w') as f:
    f.write(file)
# Out:
# [
#     {
#         "id": 1,
#         "name": "Student 1",
#         "nim": "2602127781",
#         "avatar": "defaultAvatar",
#         "email": "student1@binus.ac.id",
#         "password": "a",
#         "classes": [
#             {
#                 "instructorAvatar": "instructorDefaultAvatar",
#                 "instructor": "Franz",
#                 "course": "Linear Algebra"
#             },
#             {
#                 "instructorAvatar": "instructorDefaultAvatar",
#                 "instructor": "Franz",
#                 "course": "Calculus"
#             },
#             {
#                 "instructorAvatar": "instructorDefaultAvatar",
#                 "instructor": "Franz",
#                 "course": "Human Computer Interaction"
#             },
#             {
#                 "instructorAvatar": "instructorDefaultAvatar",
#                 "instructor": "Franz",
#                 "course": "Model Deployment"
#             },
#             {
# ...
